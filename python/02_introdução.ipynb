# %% [markdown]
# # Exercício 01:
#
# Dado que a lâmpada está ligada e que o bocal está queimado, qual será o resultado do nosso algoritmo?

# %% [markdown]
# <img src="/content/01-fluxograma_lampada.png" width="400" />

# %% [markdown]
# :R.:

# %%
Nesse caso, com a lâmpada ligada e bocal queimado, o resultado que o algoritmo iria mostrar é para trocar/substituir o bocal e assim solucionar o problema.

# %% [markdown]
# # Exercício 02:
#
# Qual as respostas das condicionais devo ter para receber uma resposta “Compre” no terminal?

# %% [markdown]
# <img src="./img/01-fluxograma_lampada.png" width="400" />

# %% [markdown]
# R.: As respostas teriam que ser sim para se a lâmpada está ligada e não para se o bocal está queimado, nesse caso a resposta no terminal seria "compre", já que a solução seria comprar uma nova lâmpada.

# %% [markdown]
# # Exercício 03:
#
# Dado que a lâmpada está ligada e que o bocal está queimado, qual a linha do Python que irá imprimir no terminal a resposta ao usuário?

# %%
lampada = "ligada"
bocal = "queimado"

if lampada == "ligada":
    if bocal == "queimado":
        print("Subistitua o bocal!")
    else:
        print("Compre uma nova lâmpada!")
else:
    print("Ligue a lâmpada!")
# Out:
# Subistitua o bocal!

# %% [markdown]
# R.: Nesse caso a linha 06 irá imprimir a resposta "substitua o bocal"

# %% [markdown]
# # Exercício 04:
#
# Substitua os padrões de símbolos usados no fluxograma do café:
# Qual o resultado final?

# %% [markdown]
# <img src="./img/03-fluxograma_cafe.gif" width="400" />

# %% [markdown]
# ![Captura de tela 2026-04-09 162049.png](data:image/png;base64,...)
