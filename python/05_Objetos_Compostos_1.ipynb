# %% [markdown]
# # Exercício:

# %% [markdown]
# ## 01 – Quais as vantagens da utilização de objetos compostos em detrimento dos objetos simples?

# %% [markdown]
# A maior vantagem seria para o processamento de varios dados em apenas uma variável. No objeto simples preciso de uma variável para cada objeto, ja no composto consigo organizar em listas por exemplo, facilitando a organização e entendimento dos dados.

# %% [markdown]
# ## 02 – Instancie uma variável da classe tupla, contendo 5 valores de qualquer classe, e recupere os valores:

# %%
nome_tupla = ("carro", 16.44, True, 12, ["f","e","r","r","a","r","i"])
valor_1 = nome_tupla[0]
valor_2 = nome_tupla[1]
valor_3 = nome_tupla[2]
valor_4 = nome_tupla[3]
valor_5 = nome_tupla[4]
print(valor_1), print(valor_2), print(valor_3), print(valor_4), print(valor_5)
# Out:
# carro
# 16.44
# True
# 12
# ['f', 'e', 'r', 'r', 'a', 'r', 'i']
# (None, None, None, None, None)

# %% [markdown]
# ## 03 – Instancie uma variável da classe lista, contendo 5 valores de qualquer classe, e recupere cada um dos valores:

# %%
nome_lista = ["carro", "16.44", "True", "12", "f"]
print(nome_lista[0])
print(nome_lista[1])
print(nome_lista[2])
print(nome_lista[3])
print(nome_lista[4])
# Out:
# carro
# 16.44
# True
# 12
# f

# %% [markdown]
# ## 04 – Instancie uma variável da classe lista, contendo 5 nomes de genes diferentes, recupere de cada um dos valores quantas letras ‘a’ estão presentes:

# %%
genes = ["BRCA1", "TP53", "APOE", "MTHFR", "EGFR"]
print("No gene {genes[0]} existem {genes[0].upper().count('A')} letras 'A'")
print("No gene {genes[1]} existem {genes[1].upper().count('A')} letras 'A'")
print("No gene {genes[2]} existem {genes[2].upper().count('A')} letras 'A'")
print("No gene {genes[3]} existem {genes[3].upper().count('A')} letras 'A'")
print("No gene {genes[4]} existem {genes[4].upper().count('A')} letras 'A'")
# Out:
# No gene {genes[0]} existem {genes[0].upper().count('A')} letras 'A'
# No gene {genes[1]} existem {genes[1].upper().count('A')} letras 'A'
# No gene {genes[2]} existem {genes[2].upper().count('A')} letras 'A'
# No gene {genes[3]} existem {genes[3].upper().count('A')} letras 'A'
# No gene {genes[4]} existem {genes[4].upper().count('A')} letras 'A'

# %% [markdown]
# ## 05 – Instancie uma variável da classe lista, contendo 5 valores, e recupere do segundo ao quarto valores:

# %%
nome_lista = ["carro", "16.44", "True", "12", "f"]
print(nome_lista[1:4])
# Out:
# ['16.44', 'True', '12']

# %% [markdown]
# ## 06 – Instancie uma variável da classe string com o seu nome como valor, e recupere o segundo e o último valores:

# %%
nome = "julia"
print(nome[1])
print(nome[-1])
# Out:
# u
# a

# %% [markdown]
# ## 07 – Instancie uma variável da classe dicionário com quantos valores inteiros desejar. Usando as funções globais, retorne a classe do objeto, quantos valores estão instanciados e a soma dos valores contidos no objeto:

# %%
meu_dicionario = {"A": 13, "B": 56, "C": 10, "D": 50}
classe = type(meu_dicionario)
quantidade = len(meu_dicionario)
soma_total = sum(meu_dicionario.values())
print(classe)
print(quantidade)
print(soma_total)
# Out:
# <class 'dict'>
# 4
# 129

# %% [markdown]
# ## 08 – Instancie uma variável da classe dicionário. Os index dos valores devem ser os valores contidos na lista instanciada no exercício 4 (Nomes de genes). Para isso você deve utilizar a indexação de lista. Os valores devem ser o número de caracteres em cada index. Retorne o objeto:

# %%
genes = ["BRCA1", "TP53", "APOE", "MTHFR", "EGFR"]
meu_dicionario = {
    genes[0]: len(genes[0]),
    genes[1]: len(genes[1]),
    genes[2]: len(genes[2]),
    genes[3]: len(genes[3]),
    genes[4]: len(genes[4])
}
print(meu_dicionario)
# Out:
# {'BRCA1': 5, 'TP53': 4, 'APOE': 4, 'MTHFR': 5, 'EGFR': 4}

# %% [markdown]
# ## 09 – Instancie cinco variáveis da classe lista. Cada uma delas será referente à um dos valores contidos na lista instanciada no exercício 4 (Nomes dos genes). Em cada uma das listas, você deve inserir o número de caracteres presentes no nome do gene, os dois primeiros caracteres do nome, quantas vezes aparece o caractere ‘a’ e se no nome aparecem os caracteres ‘hu’. Para isso você deve utilizar a indexação de lista. Retorne cada um dos objetos:

# %%
genes = ["BRCA1", "TP53", "APOE", "MTHFR", "EGFR"]
lista_gene_0 = [
    len(genes[0]),
    genes[0][0:2],
    genes[0].lower().count('a'),
    "hu" in genes[0].lower()
]

lista_gene_1 = [
    len(genes[1]),
    genes[1][0:2],
    genes[1].lower().count('a'),
    "hu" in genes[1].lower()
]

lista_gene_2 = [
    len(genes[2]),
    genes[2][0:2],
    genes[2].lower().count('a'),
    "hu" in genes[2].lower()
]

lista_gene_3 = [
    len(genes[3]),
    genes[3][0:2],
    genes[3].lower().count('a'),
    "hu" in genes[3].lower()
]

lista_gene_4 = [
    len(genes[4]),
    genes[4][0:2],
    genes[4].lower().count('a'),
    "hu" in genes[4].lower()
]
print("Lista Gene 0")
print("Lista Gene 1")
print("Lista Gene 2")
print("Lista Gene 3")
print("Lista Gene 4")
# Out:
# Lista Gene 0
# Lista Gene 1
# Lista Gene 2
# Lista Gene 3
# Lista Gene 4

# %% [markdown]
# ## 10 – Instancie uma variável da classe dicionário, os index dos valores devem ser os valores contidos na lista instanciada no exercício 4 (Nomes dos genes). Para isso você deve utilizar a indexação de lista. Os valores devem ser as listas instanciadas no exercício 9. Retorne o objeto.

# %%
genes = ["BRCA1", "TP53", "APOE", "MTHFR", "EGFR"]
lista_gene_0 = [5, 'BR', 1, False]
lista_gene_1 = [4, 'TP', 0, False]
lista_gene_2 = [4, 'AP', 1, False]
lista_gene_3 = [5, 'MT', 0, False]
lista_gene_4 = [4, 'EG', 0, False]
dicionario_genes = {
    genes[0]: lista_gene_0,
    genes[1]: lista_gene_1,
    genes[2]: lista_gene_2,
    genes[3]: lista_gene_3,
    genes[4]: lista_gene_4
}
print(dicionario_genes)
# Out:
# {'BRCA1': [5, 'BR', 1, False], 'TP53': [4, 'TP', 0, False], 'APOE': [4, 'AP', 1, False], 'MTHFR': [5, 'MT', 0, False], 'EGFR': [4, 'EG', 0, False]}
